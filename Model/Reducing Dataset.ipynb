# %%
import pandas as pd

# %%
df = pd.read_csv("../Data/loan.csv")
# Out:
# C:\Users\Soham Mandavkar\AppData\Local\Temp\ipykernel_17168\1297779021.py:1: DtypeWarning: Columns (19,47,55,112,123,124,125,128,129,130,133,139,140,141) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../Data/loan.csv")

# %%
df.shape
# Out:
# (2260668, 145)

# %%
df.head(2260668)
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0       NaN        NaN       2500         2500           2500.0   36 months
# 1       NaN        NaN      30000        30000          30000.0   60 months
# 2       NaN        NaN       5000         5000           5000.0   36 months
# 3       NaN        NaN       4000         4000           4000.0   36 months
# 4       NaN        NaN      30000        30000          30000.0   60 months
# ...      ..        ...        ...          ...              ...         ...
# 2260663 NaN        NaN      12000        12000          12000.0   60 months
# 2260664 NaN        NaN      12000        12000          12000.0   60 months
# 2260665 NaN        NaN      10000        10000          10000.0   36 months
# 2260666 NaN        NaN      12000        12000          12000.0   60 months
# 2260667 NaN        NaN      16550        16550          16550.0   60 months
#
#          int_rate  installment grade sub_grade  ...  \
# ...

# %%
col = list(df.columns)
col
# Out:
# ['id',
#  'member_id',
#  'loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'desc',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'mths_since_last_delinq',
#  'mths_since_last_record',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'next_pymnt_d',
#  'last_credit_pull_d',
#  'collections_12_mths_ex_med',
#  'mths_since_last_major_derog',
#  'policy_code',
#  'application_type',
# ...

# %%
df["purpose"].unique()
# Out:
# array(['debt_consolidation', 'credit_card', 'house', 'car', 'other',
#        'vacation', 'home_improvement', 'small_business', 'major_purchase',
#        'medical', 'renewable_energy', 'moving', 'wedding', 'educational'],
#       dtype=object)

# %%
df.isnull().sum()
# Out:
# id                       2260668
# member_id                2260668
# loan_amnt                      0
# funded_amnt                    0
# funded_amnt_inv                0
#                           ...
# settlement_status        2227612
# settlement_date          2227612
# settlement_amount        2227612
# settlement_percentage    2227612
# settlement_term          2227612
# Length: 145, dtype: int64

# %%
df = df.drop(columns=df.columns[df.isnull().sum() > 100000])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2260668 entries, 0 to 2260667
# Data columns (total 82 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   loan_amnt                   int64
#  1   funded_amnt                 int64
#  2   funded_amnt_inv             float64
#  3   term                        object
#  4   int_rate                    float64
#  5   installment                 float64
#  6   grade                       object
#  7   sub_grade                   object
#  8   home_ownership              object
#  9   annual_inc                  float64
#  10  verification_status         object
#  11  issue_d                     object
#  12  loan_status                 object
#  13  pymnt_plan                  object
#  14  purpose                     object
#  15  title                       object
#  16  zip_code                    object
#  17  addr_state                  object
# ...

# %%
df.to_csv("reduced_null_LCData.csv", index=False)
